# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
df.fillna(0)
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
calorias_media = pd.DataFrame(df.groupby("Category")["Calories"].mean())
calorias_media = pd.DataFrame(calorias_media)
calorias_media = calorias_media.sort_values(by=["Calories"])

print(calorias_media)
# Out:
#                       Calories
# Category
# Beverages           113.703704
# Desserts            222.142857
# Snacks & Sides      245.769231
# Salads              270.000000
# Coffee & Tea        283.894737
# Beef & Pork         494.000000
# Breakfast           526.666667
# Smoothies & Shakes  531.428571
# Chicken & Fish      552.962963

# %%
fig, ax = plt.subplots()
x = calorias_media.index
y = calorias_media["Calories"]
ax.barh(x, y)

bars = ax.barh(x, y, color='grey')
for bar, category in zip(bars, x):
    if category == 'Desserts':  # Specify the category you want to highlight
        bar.set_color('blue')  # Change to desired color

plt.title("A SOBREMESA é o tipo de refeiçao com menos calorias no MC Donalds!!")
plt.show()

# %%
desserts = df[df['Category'] == 'Desserts']
sandwiches = df[df['Category'].isin(['Beef & Pork', 'Chicken & Fish'])]
smoothies = df[df['Category'] == 'Smoothies & Shakes']

# %%
print("Sobremesas:\n", desserts[['Item', 'Calories']].sort_values('Calories', ascending=False))
# Out:
# Sobremesas:
#                        Item  Calories
# 108     Hot Caramel Sundae       340
# 107       Hot Fudge Sundae       330
# 109      Strawberry Sundae       280
# 103        Baked Apple Pie       250
# 104  Chocolate Chip Cookie       160
# 105  Oatmeal Raisin Cookie       150
# 106    Kids Ice Cream Cone        45

# %%
print("\nLanches:\n", sandwiches[['Item', 'Calories']].sort_values('Calories', ascending=False))
# Out:
# Lanches:
#                                                   Item  Calories
# 82                       Chicken McNuggets (40 piece)      1880
# 81                       Chicken McNuggets (20 piece)       940
# 47                 Double Quarter Pounder with Cheese       750
# 63            Bacon Clubhouse Crispy Chicken Sandwich       750
# 51                             Bacon Clubhouse Burger       720
# 59               Premium Crispy Chicken Club Sandwich       670
# 74  Premium McWrap Southwest Chicken (Crispy Chicken)       670
# 70    Premium McWrap Chicken & Bacon (Crispy Chicken)       630
# 45          Quarter Pounder with Bacon Habanero Ranch       610
# 61          Premium Crispy Chicken Ranch BLT Sandwich       610
# 72    Premium McWrap Chicken & Ranch (Crispy Chicken)       610
# 44                Quarter Pounder with Bacon & Cheese       600
# 64           Bacon Clubhouse Grilled Chicken Sandwich       590
# ...

# %%
print("Sobremesas:\n", smoothies[['Item', 'Calories']].sort_values('Calories', ascending=False))
# Out:
# Sobremesas:
#                                                    Item  Calories
# 253               McFlurry with M&M’s Candies (Medium)       930
# 246                           Strawberry Shake (Large)       850
# 249                            Chocolate Shake (Large)       850
# 243                              Vanilla Shake (Large)       820
# 251                             Shamrock Shake (Large)       820
# 258  McFlurry with Reese's Peanut Butter Cups (Medium)       810
# 248                           Chocolate Shake (Medium)       700
# 245                          Strawberry Shake (Medium)       690
# 256                McFlurry with Oreo Cookies (Medium)       690
# 242                             Vanilla Shake (Medium)       660
# 250                            Shamrock Shake (Medium)       660
# 252                McFlurry with M&M’s Candies (Small)       650
# 247                            Chocolate Shake (Small)       560
# ...

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(x='Category', y='Calories', data=df[df['Category'].isin(['Desserts', 'Beef & Pork', 'Chicken & Fish', 'Smoothies & Shakes', 'Breakfast'])])
plt.title('Distribuição de Calorias: Sobremesas vs. Lanches')
plt.show()

# %%
plt.figure(figsize=(12, 5))



sns.boxplot(x='Category', y='Total Fat (% Daily Value)', data=df[df['Category'].isin(['Desserts', 'Beef & Pork', 'Chicken & Fish', 'Smoothies & Shakes', 'Breakfast'])])
plt.title('Distribuição de Calorias: Sobremesas vs. Lanches')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(x='Calories', y='Sugars', hue='Item', data=desserts)
plt.title('Calorias vs. Açúcares em Sobremesas')
plt.show()

# %%
print("Média Calorias de Gordura (Sobremesas):", desserts['Calories from Fat'].mean())
print("Média Calorias de Gordura (Lanches):", sandwiches['Calories from Fat'].mean())
# Out:
# Média Calorias de Gordura (Sobremesas): 64.28571428571429
# Média Calorias de Gordura (Lanches): 235.95238095238096

# %%
# Filtrar as categorias desejadas
filtered_df = df[df['Category'].isin(['Desserts', 'Beef & Pork', 'Chicken & Fish', 'Smoothies & Shakes', 'Breakfast'])]

# Definir uma paleta de cores personalizada: azul para 'Desserts', cinza para as demais
colors = ['blue' if cat == 'Desserts' else 'grey' for cat in filtered_df['Category'].unique()]

# Barplot comparativo
plt.figure(figsize=(8, 6))
sns.barplot(x='Category', y='Calories from Fat', hue='Category', data=filtered_df, palette=colors, legend=False)
plt.title('Calorias Provenientes de Gordura por Categoria')
plt.show()
